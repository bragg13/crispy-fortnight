# %%
import matplotlib.pyplot as plt

# %%
experiment = [0,1,2,4,8,16,32]
token_acc = [0.57024*100, 0.62027*100, 0.7703*100, 0.7810*100, 0.7960*100, 0.8627*100, 0.9117*100]
seq_acc = [0.001  *100, 0.02972*100, 0.1733*100, 0.2487*100, 0.317*100, 0.511*100, 0.6443*100]

# Adjusting the bar chart to have equal spacing between bars
plt.figure(1)
plt.bar(range(len(experiment)), token_acc, width=0.6, color='blue', alpha=0.7)

# Setting x-ticks to the experiment values and ensuring equal spacing
plt.xticks(range(len(experiment)), experiment)

# Adding labels and title
plt.xlabel("Experiment", fontsize=12)
plt.ylabel("Token Accuracy (%)", fontsize=12)
plt.title("Token Accuracy Across Experiments", fontsize=14)

# Display the plot
plt.show()

plt.figure(2)
plt.bar(range(len(experiment)), seq_acc, width=0.6, color='blue', alpha=0.7)

# Setting x-ticks to the experiment values and ensuring equal spacing
plt.xticks(range(len(experiment)), experiment)

# Adding labels and title
plt.xlabel("Experiment", fontsize=12)
plt.ylabel("Sequence Accuracy (%)", fontsize=12)
plt.title("Sequence Accuracy Across Experiments", fontsize=14)

# Display the plot
plt.show()

# %%
experiment = [0,1,2,4,8,16,32]
token_acc = [0.5685*100, 0.6207*100, 0.7642*100, 0.8463*100, 0.7771*100, 0.8728*100, 0.9281*100]
seq_acc = [0.0013*100, 0.0631*100, 0.1933*100, 0.4401*100, 0.2339*100, 0.4871*100, 0.6701*100]

# Adjusting the bar chart to have equal spacing between bars
plt.figure(1)
plt.bar(range(len(experiment)), token_acc, width=0.6, color='blue', alpha=0.7)

# Setting x-ticks to the experiment values and ensuring equal spacing
plt.xticks(range(len(experiment)), experiment)

# Adding labels and title
plt.xlabel("Experiment", fontsize=12)
plt.ylabel("Token Accuracy (%)", fontsize=12)
plt.title("Token Accuracy Across Experiments", fontsize=14)

# Display the plot
plt.show()

plt.figure(2)
plt.bar(range(len(experiment)), seq_acc, width=0.6, color='blue', alpha=0.7)

# Setting x-ticks to the experiment values and ensuring equal spacing
plt.xticks(range(len(experiment)), experiment)

# Adding labels and title
plt.xlabel("Experiment", fontsize=12)
plt.ylabel("Sequence Accuracy (%)", fontsize=12)
plt.title("Sequence Accuracy Across Experiments", fontsize=14)

# Display the plot
plt.show()

# %% [markdown]
# 1 composed command:
#
# ```
# 0.62027   0.64515    0.64803     0.75489     0.71285
# 0.02972   0.01705    0.05269     0.21384     0.08523
# ```
#
# 2 composed commands:
#
# ```
# 0.70051   0.71346    0.68426     0.68562     0.72109
# 0.10986   0.12267    0.10326     0.07725     0.12500
# ```
#
# 4 composed commands:
#
# ```
# 0.77142   0.71605    0.80434     0.68987     0.75799
# 0.30473   0.16964    0.33229     0.12810     0.24495
# ```
#
# 8 composed commands:
#
# ```
# 0.82722   0.76970    0.77518     0.79509     0.79331
# 0.32763   0.25155    0.29153     0.27329     0.26319
# ```
#
# 16 composed commands:
#
# ```
# 0.89126   0.82258    0.87313     0.81350     0.82938
# 0.54503   0.38392    0.51630     0.35170     0.38354
# ```
#
# 32 composed commands:
# ```
# 0.91040   0.91235    0.91637     0.90632     0.91085
# 0.55900   0.63121    0.64285     0.90632     0.62461
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data from the tables
num_composed_commands = [0, 1, 2, 4, 8, 16, 32]  # Original labels
x_positions = np.arange(len(num_composed_commands))  # Evenly spaced positions

token_accuracy = [
    0.67624, 0.62027, 0.70099, 0.74793, 0.79210, 0.84597, 0.91126  # Average of token accuracies
]
sequence_accuracy = [
    0.00100, 0.07971, 0.10761, 0.235942, 0.28144, 0.43610, 0.67280  # Average of sequence accuracies
]

# Creating the plots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Token-Level Accuracy Plot
axes[0].bar(x_positions, np.array(token_accuracy) * 100, width=0.8)
axes[0].set_title("Token-Level Accuracy")
axes[0].set_xlabel("Number of Composed Commands Used For Training")
axes[0].set_ylabel("Accuracy on New Commands (%)")
axes[0].set_xticks(x_positions)
axes[0].set_xticklabels(num_composed_commands)
axes[0].set_ylim(0, 100)

# Sequence-Level Accuracy Plot
axes[1].bar(x_positions, np.array(sequence_accuracy) * 100, width=0.8)
axes[1].set_title("Sequence-Level Accuracy")
axes[1].set_xlabel("Number of Composed Commands Used For Training")
axes[1].set_ylabel("Accuracy on New Commands (%)")
axes[1].set_xticks(x_positions)
axes[1].set_xticklabels(num_composed_commands)
axes[1].set_ylim(0, 60)

# Adjust spacing and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each composed command group (5 values per group)
token_accuracy = {
    1: [0.62027, 0.64515, 0.64803, 0.75489, 0.71285],
    2: [0.70051, 0.71346, 0.68426, 0.68562, 0.72109],
    4: [0.77142, 0.71605, 0.80434, 0.68987, 0.75799],
    8: [0.82722, 0.76970, 0.77518, 0.79509, 0.79331],
    16: [0.89126, 0.82258, 0.87313, 0.81350, 0.82938],
    32: [0.91040, 0.91235, 0.91637, 0.90632, 0.91085]
}

sequence_accuracy = {
    1: [0.02972, 0.01705, 0.05269, 0.21384, 0.08523],
    2: [0.10986, 0.12267, 0.10326, 0.07725, 0.12500],
    4: [0.30473, 0.16964, 0.33229, 0.12810, 0.24495],
    8: [0.32763, 0.25155, 0.29153, 0.27329, 0.26319],
    16: [0.54503, 0.38392, 0.51630, 0.35170, 0.38354],
    32: [0.55900, 0.63121, 0.64285, 0.90632, 0.62461]
}

# Define the number of composed commands (group labels)
num_composed_commands = [1, 2, 4, 8, 16, 32]
x_positions = np.arange(len(num_composed_commands)) * 10  # Multiply by 10 to space out the groups

# Create the figure and subplots
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Token-Level Accuracy Plot
for i, num in enumerate(num_composed_commands):
    axes[0].scatter(np.full_like(token_accuracy[num], x_positions[i]), token_accuracy[num], label=f'{num} Commands')
axes[0].set_title("Token-Level Accuracy")
axes[0].set_xlabel("Number of Composed Commands Used For Training")
axes[0].set_ylabel("Accuracy on New Commands (%)")
axes[0].set_xticks(x_positions)
axes[0].set_xticklabels(num_composed_commands)
axes[0].set_ylim(0, 1)
axes[0].legend(title="Composed Commands", loc="upper left")

# Sequence-Level Accuracy Plot
for i, num in enumerate(num_composed_commands):
    axes[1].scatter(np.full_like(sequence_accuracy[num], x_positions[i]), sequence_accuracy[num], label=f'{num} Commands')
axes[1].set_title("Sequence-Level Accuracy")
axes[1].set_xlabel("Number of Composed Commands Used For Training")
axes[1].set_ylabel("Accuracy on New Commands (%)")
axes[1].set_xticks(x_positions)
axes[1].set_xticklabels(num_composed_commands)
axes[1].set_ylim(0, 1)
axes[1].legend(title="Composed Commands", loc="upper left")

# Adjust spacing and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for each composed command group (5 values per group)
token_accuracy = {
    1: [0.62027, 0.64515, 0.64803, 0.75489, 0.71285],
    2: [0.70051, 0.71346, 0.68426, 0.68562, 0.72109],
    4: [0.77142, 0.71605, 0.80434, 0.68987, 0.75799],
    8: [0.82722, 0.76970, 0.77518, 0.79509, 0.79331],
    16: [0.89126, 0.82258, 0.87313, 0.81350, 0.82938],
    32: [0.91040, 0.91235, 0.91637, 0.90632, 0.91085]
}

sequence_accuracy = {
    1: [0.02972, 0.01705, 0.05269, 0.21384, 0.08523],
    2: [0.10986, 0.12267, 0.10326, 0.07725, 0.12500],
    4: [0.30473, 0.16964, 0.33229, 0.12810, 0.24495],
    8: [0.32763, 0.25155, 0.29153, 0.27329, 0.26319],
    16: [0.54503, 0.38392, 0.51630, 0.35170, 0.38354],
    32: [0.55900, 0.63121, 0.64285, 0.90632, 0.62461]
}

# Define the number of composed commands (group labels)
num_composed_commands = [1, 2, 4, 8, 16, 32]
x_positions = np.arange(len(num_composed_commands)) * 10  # Multiply by 10 to space out the groups

# Create the figure and subplots
fig, axes = plt.subplots(2, 1, figsize=(12, 10))

# Plot Token-Level Accuracy
for i, num in enumerate(num_composed_commands):
    # Plot the average values as bars
    axes[0].bar(x_positions[i], np.mean(token_accuracy[num]), width=6, color='lightblue', label=f'{num} Commands' if i == 0 else "")
    # Overlay the scatter points for individual values
    axes[0].scatter(np.full_like(token_accuracy[num], x_positions[i]), token_accuracy[num], color='blue')
axes[0].set_title("Token-Level Accuracy")
axes[0].set_xlabel("Number of Composed Commands Used For Training")
axes[0].set_ylabel("Accuracy on New Commands (%)")
axes[0].set_xticks(x_positions)
axes[0].set_xticklabels(num_composed_commands)
axes[0].set_ylim(0, 1)
axes[0].legend(title="Composed Commands", loc="upper left")

# Plot Sequence-Level Accuracy
for i, num in enumerate(num_composed_commands):
    # Plot the average values as bars
    axes[1].bar(x_positions[i], np.mean(sequence_accuracy[num]), width=6, color='lightgreen', label=f'{num} Commands' if i == 0 else "")
    # Overlay the scatter points for individual values
    axes[1].scatter(np.full_like(sequence_accuracy[num], x_positions[i]), sequence_accuracy[num], color='green')
axes[1].set_title("Sequence-Level Accuracy")
axes[1].set_xlabel("Number of Composed Commands Used For Training")
axes[1].set_ylabel("Accuracy on New Commands (%)")
axes[1].set_xticks(x_positions)
axes[1].set_xticklabels(num_composed_commands)
axes[1].set_ylim(0, 1)
axes[1].legend(title="Composed Commands", loc="upper left")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()
